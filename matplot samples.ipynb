# %%
# !pip install matplotlib pandas numpy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Sample data
data = {
    'Metric': ['Accuracy', 'Error Rate'],
    'Before Adaptive Algorithm': [0.75, 0.25],  # Example values
    'After Adaptive Algorithm': [0.85, 0.15]    # Example values
}

# Create DataFrame
df = pd.DataFrame(data)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Bar plot
df.set_index('Metric').plot(kind='bar', ax=ax, color=['#1f77b4', '#ff7f0e'])

# Adding labels
plt.title('Performance Metrics Before and After Adaptive Algorithm')
plt.xlabel('Metric')
plt.ylabel('Value')
plt.xticks(rotation=0)
plt.legend(title='Algorithm Status')

# Show plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
data = {
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Before': [0.78, 0.76, 0.74, 0.75],
    'After': [0.85, 0.83, 0.81, 0.82]
}

df = pd.DataFrame(data)

# Create heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.set_index('Metric'), annot=True, cmap="YlGnBu", cbar=True, linewidths=0.5)

plt.title('Performance Metrics Before and After Adaptive Algorithm')
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
before = [0.78, 0.76, 0.74, 0.75]
after = [0.85, 0.83, 0.81, 0.82]

plt.plot(metrics, before, marker='o', label='Before Adaptive Algorithm', color='r')
plt.plot(metrics, after, marker='o', label='After Adaptive Algorithm', color='g')

plt.title('Performance Metrics Before and After Adaptive Algorithm')
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# Data
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
before = [0.78, 0.76, 0.74, 0.75]
after = [0.85, 0.83, 0.81, 0.82]

# Number of variables
num_vars = len(metrics)

# Create radar chart
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
before += before[:1]  # Repeat the first value to close the circle
after += after[:1]  # Repeat the first value to close the circle
angles += angles[:1]

# Create the radar chart
fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(polar=True))
ax.fill(angles, before, color='red', alpha=0.25, label='Before')
ax.fill(angles, after, color='green', alpha=0.25, label='After')

ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)

plt.title('Performance Comparison: Before vs. After Adaptive Algorithm')
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
data = {
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1 Score'],
    'Before': [0.78, 0.76, 0.74, 0.75],
    'After': [0.85, 0.83, 0.81, 0.82]
}

df = pd.DataFrame(data)

# Melt data for better plotting
df_melted = df.melt(id_vars='Metric', var_name='Algorithm', value_name='Value')

# Create boxplot
plt.figure(figsize=(8,6))
sns.boxplot(x='Metric', y='Value', hue='Algorithm', data=df_melted, palette='Set1')

plt.title('Performance Metrics Comparison: Before and After Adaptive Algorithm')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Set up the figure
fig, ax = plt.subplots(figsize=(10, 8))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Add a title
ax.text(0.5, 0.95, 'AI Overview: Key Highlights', ha='center', va='center', fontsize=16, fontweight='bold')

# Define the points
points = [
    ("AI simulates human intelligence using algorithms and data.",
     "blue"),
    ("Key capabilities: learning, automating, and predicting.",
     "green"),
    ("Drives innovation in healthcare, finance, and technology.",
     "red"),
    ("Enhances efficiency, decision-making, and user experiences.",
     "purple")
]

# Add each point to the plot
for i, (text, color) in enumerate(points):
    # Create a rectangle for each point
    rect = patches.FancyBboxPatch((0.05, 0.75 - i*0.2), 0.9, 0.15, boxstyle="round,pad=0.1", 
                                  edgecolor='black', facecolor=color, alpha=0.5)
    ax.add_patch(rect)
    # Add text inside the rectangle
    ax.text(0.5, 0.82 - i*0.2, text, ha='center', va='center', fontsize=12, color='white', fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the points
labels = [
    "Simulates human intelligence using algorithms and data.",
    "Key capabilities: learning, automating, and predicting.",
    "Drives innovation in healthcare, finance, and technology.",
    "Enhances efficiency, decision-making, and user experiences."
]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Set up the figure
fig, ax = plt.subplots(figsize=(10, 10))
ax.axis('off')

# Create a circle for the central point
circle = plt.Circle((0.5, 0.5), 0.4, color='lightgray', alpha=0.3, transform=ax.transAxes)
ax.add_artist(circle)

# Create the segments
num_points = len(labels)
theta = np.linspace(0, 2 * np.pi, num_points + 1)
radius = 0.4

# Create segments and text
for i in range(num_points):
    # Calculate segment positions
    start_angle = theta[i]
    end_angle = theta[i + 1]
    
    # Define the wedge
    wedge = patches.Wedge(center=(0.5, 0.5), r=radius, theta1=np.degrees(start_angle), theta2=np.degrees(end_angle),
                          facecolor=colors[i], edgecolor='black', linewidth=1, transform=ax.transAxes)
    ax.add_patch(wedge)
    
    # Add text
    text_angle = (start_angle + end_angle) / 2
    x_text = 0.5 + (radius / 2) * np.cos(text_angle)
    y_text = 0.5 + (radius / 2) * np.sin(text_angle)
    ax.text(x_text, y_text, labels[i], ha='center', va='center', fontsize=12, color='white', fontweight='bold', transform=ax.transAxes)

# Add central title
ax.text(0.5, 0.5, 'AI Overview', ha='center', va='center', fontsize=20, fontweight='bold', transform=ax.transAxes)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the points
labels = [
    "Simulates human intelligence\nusing algorithms and data.",
    "Key capabilities: learning,\nautomating, and predicting.",
    "Drives innovation in healthcare,\nfinance, and technology.",
    "Enhances efficiency,\ndecision-making, and user experiences."
]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Number of points
num_points = len(labels)

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
ax.set_theta_offset(np.pi / 2)  # Rotate the chart to start from the top
ax.set_theta_direction(-1)  # Make the chart clockwise

# Define the angles for each segment
angles = np.linspace(0, 2 * np.pi, num_points, endpoint=False).tolist()

# Close the circle
angles += angles[:1]
colors += colors[:1]

# Create the radial bars
for i in range(num_points):
    bar = plt.Circle((0, 0), 1, transform=ax.transData._b, edgecolor='black', facecolor=colors[i], alpha=0.6)
    ax.add_patch(bar)
    ax.text(angles[i], 1.2, labels[i], ha='center', va='center', fontsize=12, color='black')

# Adjust the layout
ax.set_ylim(0, 1.5)  # Extend the radius to fit labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=12, fontweight='bold')

# Remove grid and labels
ax.grid(False)
ax.set_yticklabels([])
ax.set_yticks([])

# Add title
plt.title('AI Overview: Key Highlights', fontsize=16, fontweight='bold', y=1.1)

# Show the plot
plt.show()

# %%
# !pip install matplotlib pillow requests
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO
import numpy as np

# Function to load image from URL
def load_image(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    return img

# Icon URLs
icons = {
    "AI Intelligence": 'https://img.icons8.com/ios/50/000000/brain.png',
    "Capabilities": 'https://img.icons8.com/ios/50/000000/automation.png',
    "Innovation": 'https://img.icons8.com/ios/50/000000/innovation.png',
    "Impact": 'https://img.icons8.com/ios/50/000000/efficiency.png'
}

# Data for the points
labels = [
    "AI simulates human intelligence\nusing algorithms and data.",
    "Key capabilities: learning,\nautomating, and predicting.",
    "Drives innovation in healthcare,\nfinance, and technology.",
    "Enhances efficiency,\ndecision-making, and user experiences."
]

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Timeline coordinates
y_positions = np.linspace(0.8, 0.2, len(labels))

# Add icons and text to the plot
for i, (label, icon_url) in enumerate(zip(labels, icons.values())):
    # Load and display the icon
    img = load_image(icon_url)
    img = img.resize((50, 50))  # Resize the image to fit the plot
    imagebox = OffsetImage(img, zoom=1.0)
    ab = AnnotationBbox(imagebox, (0.1, y_positions[i]), frameon=False, pad=0.1, xycoords='axes fraction', boxcoords="axes fraction")
    ax.add_artist(ab)
    
    # Add text
    ax.text(0.25, y_positions[i], label, ha='left', va='center', fontsize=12, fontweight='bold', bbox=dict(facecolor='lightgrey', alpha=0.5, boxstyle='round,pad=0.3'))

# Add title
plt.title('AI Overview: Key Highlights', fontsize=16, fontweight='bold')

# Show the plot
plt.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[31], line 44
#      41 # Add icons and text to the plot
#      42 for i, (label, icon_url) in enumerate(zip(labels, icons.values())):
#      43     # Load and display the icon
# ---> 44     img = load_image(icon_url)
#      45     img = img.resize((50, 50))  # Resize the image to fit the plot
#      46     imagebox = OffsetImage(img, zoom=1.0)
#
# Cell In[31], line 13, in load_image(url)
#      11 def load_image(url):
#      12     response = requests.get(url)
# ---> 13     img = Image.open(BytesIO(response.content))
#      14     return img
#
# File D:\jupyter notebook\Lib\site-packages\PIL\Image.py:3339, in open(fp, mode, formats)
#    3337     warnings.warn(message)
#    3338 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3339 raise UnidentifiedImageError(msg)
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO
import numpy as np

# Function to load image from URL with error handling
def load_image(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        img = Image.open(BytesIO(response.content))
        img.verify()  # Verify that it is an image
        img = Image.open(BytesIO(response.content))  # Re-open image after verification
        return img
    except Exception as e:
        print(f"Error loading image from {url}: {e}")
        return None

# Icon URLs
icons = {
    "AI Intelligence": 'https://img.icons8.com/ios/50/000000/brain.png',
    
    "Innovation": 'https://img.icons8.com/ios/50/000000/innovation.png',
  
}

# Data for the points
labels = [
    " human intelligence\nusing algorithms and data.",
    "Key capabilities: learning,\nautomating, and predicting.",
    "Drives innovation in healthcare,\nfinance, and technology.",
    "Enhances efficiency,\ndecision-making, and user experiences."
]

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Timeline coordinates
y_positions = np.linspace(0.8, 0.2, len(labels))

# Add icons and text to the plot
for i, (label, icon_url) in enumerate(zip(labels, icons.values())):
    # Load and display the icon
    img = load_image(icon_url)
    if img is not None:
        img = img.resize((50, 50))  # Resize the image to fit the plot
        imagebox = OffsetImage(img, zoom=1.0)
        ab = AnnotationBbox(imagebox, (0.1, y_positions[i]), frameon=False, pad=0.1, xycoords='axes fraction', boxcoords="axes fraction")
        ax.add_artist(ab)
    
    # Add text
    ax.text(0.25, y_positions[i], label, ha='left', va='center', fontsize=12, fontweight='bold', bbox=dict(facecolor='lightgrey', alpha=0.5, boxstyle='round,pad=0.3'))

# Add title
plt.title('AI', fontsize=16, fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define stages of AI evolution
stages = {
    "AI 1.0": "Rule-based systems\nStatic and deterministic\nLimited to predefined rules",
    "AI 2.0": "Data-driven systems\nMachine Learning\nImproved by data input",
    "AI 3.0": "Deep Learning\nBig Data\nNeural networks, feature extraction",
    "AI 4.0": "Limited Flexibility\nStatic Algorithms\nStruggles with dynamic environments"
}

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Define positions for each stage
y_positions = [0.8, 0.6, 0.4, 0.2]
x_center = 0.5

# Add stages to the plot
for i, (stage, description) in enumerate(stages.items()):
    # Add rectangle for each stage
    rect = patches.FancyBboxPatch(
        (x_center - 0.2, y_positions[i] - 0.1), 0.4, 0.2,
        boxstyle="round,pad=0.1", edgecolor='black', facecolor='lightblue',
        linewidth=2
    )
    ax.add_patch(rect)
    
    # Add text for each stage
    ax.text(x_center, y_positions[i], f'{stage}\n{description}',
            ha='center', va='center', fontsize=12, fontweight='bold',
            bbox=dict(facecolor='lightblue', edgecolor='black', boxstyle='round,pad=0.1'))

    # Draw arrows
    if i < len(stages) - 1:
        ax.annotate("", xy=(x_center, y_positions[i + 1] + 0.1), xytext=(x_center, y_positions[i] - 0.1),
                    arrowprops=dict(arrowstyle="->", color='black', lw=2))

# Add title
plt.title('Evolution of AI: From AI 1.0 to AI 4.0', fontsize=16, fontweight='bold')

# Show the plot
plt.show()

# %%
import plotly.graph_objects as go

# Define stages of AI evolution
stages = {
    "AI 1.0": "Rule-based systems\nStatic and deterministic\nLimited to predefined rules",
    "AI 2.0": "Data-driven systems\nMachine Learning\nImproved by data input",
    "AI 3.0": "Deep Learning\nBig Data\nNeural networks, feature extraction",
    "AI 4.0": "Limited Flexibility\nStatic Algorithms\nStruggles with dynamic environments"
}

# Data for the plot
stage_names = list(stages.keys())
descriptions = list(stages.values())
y_positions = list(range(len(stages)))

# Create figure
fig = go.Figure()

# Add stages to the plot
for i, (stage, description) in enumerate(stages.items()):
    fig.add_trace(go.Scatter(
        x=[0],
        y=[i],
        mode='markers+text',
        text=[f'{stage}: {description}'],
        textposition='top center',
        marker=dict(size=20, color='royalblue'),
        name=stage
    ))

# Customize layout
fig.update_layout(
    title='Evolution of AI: From AI 1.0 to AI 4.0',
    yaxis=dict(
        tickvals=y_positions,
        ticktext=stage_names,
        title='AI Stages'
    ),
    xaxis=dict(
        title='Details'
    ),
    showlegend=False
)

# Show interactive plot
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define stages of AI evolution
stages = {
    "AI 1.0": "Rule-based systems\nStatic and deterministic\nLimited to predefined rules",
    "AI 2.0": "Data-driven systems\nMachine Learning\nImproved by data input",
    "AI 3.0": "Deep Learning\nBig Data\nNeural networks, feature extraction",
    "AI 4.0": "Limited Flexibility\nStatic Algorithms\nStruggles with dynamic environments"
}

# Data for the plot
labels = list(stages.keys())
descriptions = list(stages.values())
num_stages = len(labels)
angles = np.linspace(0, 2 * np.pi, num_stages, endpoint=False).tolist()
angles += angles[:1]  # Complete the circle

# Setup plot
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.set_ylim(0, 1)
ax.set_yticklabels([])

# Add stages to the plot
for i in range(num_stages):
    angle = angles[i]
    ax.text(angle, 0.5, labels[i], horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold')
    ax.text(angle, 0.4, descriptions[i], horizontalalignment='center', verticalalignment='center', fontsize=10, bbox=dict(facecolor='lightblue', alpha=0.5))

# Add title
ax.set_title('Evolution of AI: From AI 1.0 to AI 4.0', fontsize=16, fontweight='bold', pad=20)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import requests
from io import BytesIO

# Function to load image from URL
def load_image(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        img = Image.open(BytesIO(response.content))
        img = img.resize((50, 50))
        return img
    except Exception as e:
        print(f"Error loading image from {url}: {e}")
        return None

# Icon URLs
icons = {
    "AI 1.0": 'https://img.icons8.com/ios/50/000000/rule-based.png',  # Example icon
    "AI 2.0": 'https://img.icons8.com/ios/50/000000/machine-learning.png',
    "AI 3.0": 'https://img.icons8.com/ios/50/000000/deep-learning.png',
    "AI 4.0": 'https://img.icons8.com/ios/50/000000/automation.png'
}

# Data for the points
labels = [
    "AI 1.0: Rule-based systems\nStatic and deterministic",
    "AI 2.0: Data-driven systems\nMachine Learning",
    "AI 3.0: Deep Learning\nBig Data",
    "AI 4.0: Limited Flexibility\nStatic Algorithms"
]

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Timeline coordinates
y_positions = np.linspace(0.8, 0.2, len(labels))

# Add icons and text to the plot
for i, (label, icon_url) in enumerate(zip(labels, icons.values())):
    # Load and display the icon
    img = load_image(icon_url)
    if img is not None:
        imagebox = OffsetImage(img, zoom=1.0)
        ab = AnnotationBbox(imagebox, (0.1, y_positions[i]), frameon=False, pad=0.1, xycoords='axes fraction', boxcoords="axes fraction")
        ax.add_artist(ab)
    
    # Add text
    ax.text(0.25, y_positions[i], label, ha='left', va='center', fontsize=12, fontweight='bold', bbox=dict(facecolor='lightgrey', alpha=0.5, boxstyle='round,pad=0.3'))

# Add title
plt.title('AI Evolution: From AI 1.0 to AI 4.0', fontsize=16, fontweight='bold')

# Show the plot
plt.show()
# Out:
# Error loading image from https://img.icons8.com/ios/50/000000/rule-based.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/50/000000/rule-based.png
# Error loading image from https://img.icons8.com/ios/50/000000/deep-learning.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/50/000000/deep-learning.png
# Error loading image from https://img.icons8.com/ios/50/000000/automation.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/50/000000/automation.png

# %%
import matplotlib.pyplot as plt

# Define stages of AI evolution
stages = ["AI 1.0", "AI 2.0", "AI 3.0", "AI 4.0"]
descriptions = ["Rule-based systems", "Data-driven systems", "Deep Learning", "Limited Flexibility"]

# Data for the plot
y_pos = range(len(stages))
length = [1] * len(stages)  # Uniform length for bars

# Create bar chart
fig, ax = plt.subplots(figsize=(10, 4))
bars = ax.barh(y_pos, length, color='royalblue', edgecolor='black')

# Add labels and descriptions
for bar, stage, description in zip(bars, stages, descriptions):
    ax.text(bar.get_width() + 0.05, bar.get_y() + bar.get_height()/2, f'{stage}: {description}', 
            va='center', fontsize=12, fontweight='bold')

# Customize layout
ax.set_yticks(y_pos)
ax.set_yticklabels(stages)
ax.set_xlim(0, 1.2)  # Extra space for text
ax.set_title('Evolution of AI: From AI 1.0 to AI 4.0', fontsize=16, fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from PIL import Image
import requests
from io import BytesIO

# Function to load image from URL
def load_image(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        img = Image.open(BytesIO(response.content))
        img = img.resize((50, 50))
        return img
    except Exception as e:
        print(f"Error loading image from {url}: {e}")
        return None

# Icon URLs
icons = {
    "AI 1.0": 'https://img.icons8.com/ios/50/000000/rule-based.png',  # Example icon
    "AI 2.0": 'https://img.icons8.com/ios/50/000000/machine-learning.png',
    "AI 3.0": 'https://img.icons8.com/ios/50/000000/deep-learning.png',
    "AI 4.0": 'https://img.icons8.com/ios/50/000000/automation.png'
}

# Data for the points
labels = ["AI 1.0", "AI 2.0", "AI 3.0", "AI 4.0"]
descriptions = ["Rule-based", "Data-driven", "Deep Learning", "Limited Flexibility"]

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 4))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Timeline coordinates
x_positions = np.linspace(0.1, 0.9, len(labels))

# Add icons and text to the plot
for i, (label, icon_url, description) in enumerate(zip(labels, icons.values(), descriptions)):
    # Load and display the icon
    img = load_image(icon_url)
    if img is not None:
        imagebox = OffsetImage(img, zoom=1.0)
        ab = AnnotationBbox(imagebox, (x_positions[i], 0.6), frameon=False, pad=0.1, xycoords='axes fraction', boxcoords="axes fraction")
        ax.add_artist(ab)
    
    # Add text
    ax.text(x_positions[i], 0.4, f'{label}\n{description}', ha='center', va='center', fontsize=12, fontweight='bold', bbox=dict(facecolor='lightgrey', alpha=0.5, boxstyle='round,pad=0.3'))

# Add title
plt.title('Evolution of AI: From AI 1.0 to AI 4.0', fontsize=16, fontweight='bold')

# Show the plot
plt.show()
# Out:
# Error loading image from https://img.icons8.com/ios/50/000000/rule-based.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/50/000000/rule-based.png
# Error loading image from https://img.icons8.com/ios/50/000000/deep-learning.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/50/000000/deep-learning.png
# Error loading image from https://img.icons8.com/ios/50/000000/automation.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/50/000000/automation.png

# %%
import matplotlib.pyplot as plt

# Define stages of AI evolution with accuracy and efficiency
stages = {
    "AI 1.0": {"accuracy": 0.3, "efficiency": 0.2},
    "AI 2.0": {"accuracy": 0.5, "efficiency": 0.4},
    "AI 3.0": {"accuracy": 0.7, "efficiency": 0.6},
    "AI 4.0": {"accuracy": 0.8, "efficiency": 0.7},
}

# Extract data
labels = list(stages.keys())
accuracy = [stages[label]["accuracy"] for label in labels]
efficiency = [stages[label]["efficiency"] for label in labels]

# Create scatter plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(accuracy, efficiency, color='royalblue', s=100, edgecolor='black')

# Add labels and descriptions
for label, acc, eff in zip(labels, accuracy, efficiency):
    ax.text(acc, eff, label, fontsize=12, ha='center', va='center', bbox=dict(facecolor='lightgrey', alpha=0.7))

# Customize layout
ax.set_xlabel('Accuracy')
ax.set_ylabel('Efficiency')
ax.set_title('Evolution of AI: Accuracy vs Efficiency', fontsize=16, fontweight='bold')

# Show the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define stages of AI evolution with accuracy, efficiency, and significance (size)
stages = {
    "AI 1.0": {"accuracy": 0.3, "efficiency": 0.2, "size": 100},
    "AI 2.0": {"accuracy": 0.5, "efficiency": 0.4, "size": 200},
    "AI 3.0": {"accuracy": 0.7, "efficiency": 0.6, "size": 300},
    "AI 4.0": {"accuracy": 0.8, "efficiency": 0.7, "size": 400},
}

# Extract data
labels = list(stages.keys())
accuracy = [stages[label]["accuracy"] for label in labels]
efficiency = [stages[label]["efficiency"] for label in labels]
sizes = [stages[label]["size"] for label in labels]

# Create bubble chart
fig, ax = plt.subplots(figsize=(8, 6))
scatter = ax.scatter(accuracy, efficiency, s=sizes, alpha=0.5, edgecolor='black', c='royalblue')

# Add labels
for label, acc, eff in zip(labels, accuracy, efficiency):
    ax.text(acc, eff, label, fontsize=12, ha='center', va='center', bbox=dict(facecolor='lightgrey', alpha=0.7))

# Customize layout
ax.set_xlabel('Accuracy')
ax.set_ylabel('Efficiency')
ax.set_title('Evolution of AI: Accuracy, Efficiency, and Significance', fontsize=16, fontweight='bold')

# Show the plot
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import requests
from io import BytesIO

# Function to load image from URL
def load_image(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        img = Image.open(BytesIO(response.content))
        img = img.resize((60, 60))
        return img
    except Exception as e:
        print(f"Error loading image from {url}: {e}")
        return None

# Icon URLs
icons = {
    "AI 1.0": 'https://img.icons8.com/ios/60/000000/rule-based.png',  # Example icon
    "AI 2.0": 'https://img.icons8.com/ios/60/000000/machine-learning.png',
    "AI 3.0": 'https://img.icons8.com/ios/60/000000/deep-learning.png',
    "AI 4.0": 'https://img.icons8.com/ios/60/000000/automation.png'
}

# Data for the points
labels = ["AI 1.0", "AI 2.0", "AI 3.0", "AI 4.0"]
positions = [1, 2, 3, 4]
descriptions = ["Rule-based", "Data-driven", "Deep Learning", "Limited Flexibility"]

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))
ax.set_xlim(0, 5)
ax.set_ylim(0, 1)
ax.axis('off')

# Add icons and text to the plot
for i, (label, icon_url, description) in enumerate(zip(labels, icons.values(), descriptions)):
    # Load and display the icon
    img = load_image(icon_url)
    if img is not None:
        imagebox = OffsetImage(img, zoom=1.0)
        ab = AnnotationBbox(imagebox, (positions[i], 0.5), frameon=False, pad=0.1, xycoords='data', boxcoords="data")
        ax.add_artist(ab)
    
    # Add text
    ax.text(positions[i], 0.2, f'{label}\n{description}', ha='center', va='center', fontsize=12, fontweight='bold', bbox=dict(facecolor='lightgrey', alpha=0.5, boxstyle='round,pad=0.3'))

# Add title
plt.title('AI Evolution Flowchart', fontsize=16, fontweight='bold')

# Show the plot
plt.show()
# Out:
# Error loading image from https://img.icons8.com/ios/60/000000/rule-based.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/60/000000/rule-based.png
# Error loading image from https://img.icons8.com/ios/60/000000/deep-learning.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/60/000000/deep-learning.png
# Error loading image from https://img.icons8.com/ios/60/000000/automation.png: 404 Client Error: Not Found for url: https://img.icons8.com/ios/60/000000/automation.png

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define stages of AI evolution
stages = ["AI 1.0", "AI 2.0", "AI 3.0", "AI 4.0"]
descriptions = ["Rule-based", "Data-driven", "Deep Learning", "Limited Flexibility"]
angles = np.linspace(0, 2 * np.pi, len(stages), endpoint=False).tolist()

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.set_ylim(0, 1)
ax.set_yticklabels([])
ax.set_xticks(angles)
ax.set_xticklabels(stages, fontsize=12, fontweight='bold')

# Add sectors and text
for angle, description in zip(angles, descriptions):
    ax.bar(angle, 1, width=0.1, color='royalblue', alpha=0.5)
    ax.text(angle, 0.5, description, horizontalalignment='center', verticalalignment='center', fontsize=12, fontweight='bold', bbox=dict(facecolor='lightgrey', alpha=0.5))

# Add title
plt.title('AI Evolution Circular Diagram', fontsize=16, fontweight='bold')

# Show the plot
plt.show()

# %%
import plotly.graph_objects as go

# Define stages of AI evolution with accuracy, efficiency, and significance (size)
stages = ["AI 1.0", "AI 2.0", "AI 3.0", "AI 4.0"]
accuracy = [0.3, 0.5, 0.7, 0.8]
efficiency = [0.2, 0.4, 0.6, 0.7]
sizes = [100, 200, 300, 400]  # Bubble sizes for significance

# Create bubble chart
fig = go.Figure()

fig.add_trace(go.Scatter(
    x=accuracy,
    y=efficiency,
    mode='markers+text',
    text=stages,
    textposition='top center',
    marker=dict(
        size=sizes,
        color='royalblue',
        opacity=0.6,
        line=dict(width=2, color='DarkSlateGrey')
    ),
    hovertemplate='<b>%{text}</b><br>Accuracy: %{x}<br>Efficiency: %{y}<extra></extra>',
    name='AI Evolution'
))

# Customize layout
fig.update_layout(
    title='AI Evolution: Accuracy and Efficiency with Significance',
    xaxis_title='Accuracy',
    yaxis_title='Efficiency',
    showlegend=False
)

# Show interactive plot
fig.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch
import numpy as np

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))
ax.axis('off')

# Define the sections
sections = {
    "AI 4.0": {
        "Description": "Static algorithms, limited adaptability.",
        "Icon": 'https://img.icons8.com/ios/100/000000/robot.png',  # Example icon
        "Color": 'lightcoral'
    },
    "AI 5.0": {
        "Description": "Adaptive algorithms, real-time feedback.",
        "Icon": 'https://img.icons8.com/ios/100/000000/ai.png',  # Example icon
        "Color": 'lightgreen'
    }
}

# Define positions
positions = [0.25, 0.75]

# Add content for each section
for i, (key, value) in enumerate(sections.items()):
    x_pos = positions[i]
    
    # Add the icon
    response = requests.get(value["Icon"])
    img = Image.open(BytesIO(response.content)).resize((100, 100))
    ax.imshow(img, extent=[x_pos - 0.2, x_pos + 0.2, 0.3, 0.6], aspect='auto')
    
    # Add the description box
    bbox_props = dict(boxstyle='round,pad=0.3', edgecolor=value["Color"], facecolor=value["Color"], alpha=0.5)
    ax.text(x_pos, 0.1, key, fontsize=16, fontweight='bold', ha='center', va='center', color='black')
    ax.text(x_pos, 0.2, value["Description"], fontsize=12, ha='center', va='center', bbox=bbox_props)

# Add a title
plt.title('AI Evolution: Transition from AI 4.0 to AI 5.0', fontsize=18, fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))
ax.axis('off')

# Define the stages and their features
stages = {
    "AI 4.0": ["Static Algorithms", "Limited Adaptability"],
    "AI 5.0": ["Adaptive Algorithms", "Real-Time Feedback"]
}

# Add a box for each stage
y_positions = [0.7, 0.3]
colors = ['lightcoral', 'lightgreen']

for (stage, features), y, color in zip(stages.items(), y_positions, colors):
    rect = patches.FancyBboxPatch((0.1 if stage == "AI 4.0" else 0.55, y), 0.35, 0.25, 
                                  boxstyle="round,pad=0.3", edgecolor=color, facecolor=color, alpha=0.5)
    ax.add_patch(rect)
    ax.text(0.1 if stage == "AI 4.0" else 0.55 + 0.175, y + 0.1, stage, 
            fontsize=16, fontweight='bold', ha='center', va='center')
    for i, feature in enumerate(features):
        ax.text(0.1 if stage == "AI 4.0" else 0.55 + 0.175, y + 0.05 - i*0.1, feature, 
                fontsize=12, ha='center', va='center')

# Add arrows indicating evolution
arrowprops = dict(facecolor='black', arrowstyle='->')
ax.annotate('', xy=(0.55, 0.7), xytext=(0.45, 0.7), arrowprops=arrowprops)
ax.annotate('', xy=(0.55, 0.3), xytext=(0.45, 0.3), arrowprops=arrowprops)

# Add a title
plt.title('AI Evolution: From AI 4.0 to AI 5.0', fontsize=18, fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(14, 8))
ax.axis('off')

# Define the stages and their features
stages = {
    "AI 4.0": [
        "Static Algorithms",
        "Limited Adaptability",
        "Rigid Responses",
        "Hardcoded Rules"
    ],
    "AI 5.0": [
        "Adaptive Algorithms",
        "Real-Time Feedback",
        "Contextual Awareness",
        "Continuous Learning"
    ]
}

# Define positions and colors
y_positions = [0.7, 0.3]
colors = ['lightcoral', 'lightgreen']
x_positions = [0.1, 0.55]

# Add a box for each stage
for (stage, features), y, color, x in zip(stages.items(), y_positions, colors, x_positions):
    rect = patches.FancyBboxPatch((x, y), 0.35, 0.35, 
                                  boxstyle="round,pad=0.3", edgecolor=color, facecolor=color, alpha=0.5)
    ax.add_patch(rect)
    ax.text(x + 0.175, y + 0.28, stage, fontsize=16, fontweight='bold', ha='center', va='center')
    for i, feature in enumerate(features):
        ax.text(x + 0.175, y + 0.2 - i*0.1, feature, fontsize=12, ha='center', va='center')

# Add arrows indicating evolution
arrowprops = dict(facecolor='black', arrowstyle='->')
ax.annotate('', xy=(0.55 + 0.05, 0.7), xytext=(0.45, 0.7), arrowprops=arrowprops)
ax.annotate('', xy=(0.55 + 0.05, 0.3), xytext=(0.45, 0.3), arrowprops=arrowprops)

# Add a title
plt.title('AI Evolution: From AI 4.0 to AI 5.0', fontsize=18, fontweight='bold')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Define data
stages = ["AI 4.0", "AI 5.0"]
features = {
    "Static Algorithms": 1,
    "Limited Adaptability": 1,
    "Rigid Responses": 1,
    "Hardcoded Rules": 1,
    "Adaptive Algorithms": 2,
    "Real-Time Feedback": 2,
    "Contextual Awareness": 2,
    "Continuous Learning": 2
}

# Set up the figure and 3D axis
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Create a grid
x = np.arange(len(stages))
y = np.arange(len(features))
x, y = np.meshgrid(x, y)

# Flatten the meshgrid for plotting
x = x.flatten()
y = y.flatten()
z = np.zeros_like(x)

# Define heights for bars (arbitrary for demonstration)
heights = [features.get(f, 0) for f in features]

# Create bars
ax.bar3d(x, y, z, 0.5, 0.5, heights, shade=True, color=['lightcoral' if s == 0 else 'lightgreen' for s in x])

# Customize labels
ax.set_xticks(np.arange(len(stages)))
ax.set_xticklabels(stages, fontsize=12, fontweight='bold')
ax.set_yticks(np.arange(len(features)))
ax.set_yticklabels(features.keys(), fontsize=10)
ax.set_zlabel('Importance', fontsize=12)
ax.set_title('3D Evolution of AI: From AI 4.0 to AI 5.0', fontsize=16, fontweight='bold')

# Rotate the view for better perspective
ax.view_init(elev=30, azim=150)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 36
#      33 heights = [features.get(f, 0) for f in features]
#      35 # Create bars
# ---> 36 ax.bar3d(x, y, z, 0.5, 0.5, heights, shade=True, color=['lightcoral' if s == 0 else 'lightgreen' for s in x])
#      38 # Customize labels
#      39 ax.set_xticks(np.arange(len(stages)))
#
# File D:\jupyter notebook\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Define data
stages = ["AI 4.0", "AI 5.0"]
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Create a figure and 3D axis
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(111, projection='3d')

# Define positions
x_pos = np.arange(len(stages))
y_pos = np.arange(len(features))
x, y = np.meshgrid(x_pos, y_pos)

# Flatten the meshgrid
x = x.flatten()
y = y.flatten()

# Define heights
heights = np.zeros_like(x, dtype=float)
for i, feature in enumerate(features):
    if feature in ["Adaptive Algorithms", "Real-Time Feedback", "Contextual Awareness", "Continuous Learning"]:
        heights[i + len(features)//2] = 1  # AI 5.0 features
    else:
        heights[i] = 1  # AI 4.0 features

# Create bars
ax.bar3d(x, y, np.zeros_like(x), 0.5, 0.5, heights, shade=True, color=['lightcoral' if i < len(features)//2 else 'lightgreen' for i in x])

# Customize labels
ax.set_xticks(x_pos)
ax.set_xticklabels(stages, fontsize=12, fontweight='bold')
ax.set_yticks(np.arange(len(features)))
ax.set_yticklabels(features, fontsize=10)
ax.set_zlabel('Importance', fontsize=12)
ax.set_title('3D Evolution of AI: From AI 4.0 to AI 5.0', fontsize=16, fontweight='bold')

# Rotate the view for better perspective
ax.view_init(elev=30, azim=150)

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Define data
stages = ["AI 4.0", "AI 5.0"]
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Data for plotting
x = np.arange(len(stages))
y = np.arange(len(features))
x, y = np.meshgrid(x, y)
z = np.zeros_like(x, dtype=float)

# Set z values for AI 4.0 and AI 5.0
for i in range(len(features)):
    if i < 4:  # AI 4.0 features
        z[i, 0] = 1
    else:  # AI 5.0 features
        z[i, 1] = 1

# Create a figure and 3D axis
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none', alpha=0.7)

# Customize labels
ax.set_xticks(x[0])
ax.set_xticklabels(stages, fontsize=12, fontweight='bold')
ax.set_yticks(np.arange(len(features)))
ax.set_yticklabels(features, fontsize=10)
ax.set_zlabel('Importance', fontsize=12)
ax.set_title('3D Surface Plot: Evolution from AI 4.0 to AI 5.0', fontsize=16, fontweight='bold')

plt.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Define data
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Values for AI 4.0 and AI 5.0
z_values = np.array([
    [1, 0],  # AI 4.0
    [1, 0],
    [1, 0],
    [1, 0],
    [0, 1],  # AI 5.0
    [0, 1],
    [0, 1],
    [0, 1]
])

# Create the figure
fig = go.Figure()

# Add surface plot
fig.add_trace(go.Surface(
    z=z_values.T,
    colorscale='Blues',
    showscale=True
))

# Customize layout
fig.update_layout(
    title='Interactive 3D Surface Plot: AI 4.0 to AI 5.0 Evolution',
    scene=dict(
        xaxis_title='AI Stages',
        yaxis_title='Features',
        zaxis_title='Importance',
        xaxis=dict(
            tickvals=[0, 1],
            ticktext=['AI 4.0', 'AI 5.0']
        ),
        yaxis=dict(
            tickvals=np.arange(len(features)),
            ticktext=features
        )
    ),
    height=600,
    width=800
)

fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Assign feature importance for AI 4.0 and AI 5.0
importance_AI_4_0 = np.array([1, 1, 1, 1, 0, 0, 0, 0])
importance_AI_5_0 = np.array([0, 0, 0, 0, 1, 1, 1, 1])

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Create stacked bar chart
bar_width = 0.6
index = np.arange(len(features))

bars_4_0 = ax.bar(index, importance_AI_4_0, bar_width, label='AI 4.0', color='lightcoral')
bars_5_0 = ax.bar(index, importance_AI_5_0, bar_width, bottom=importance_AI_4_0, label='AI 5.0', color='lightgreen')

# Add labels and title
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Importance', fontsize=12)
ax.set_title('Feature Importance Transition from AI 4.0 to AI 5.0', fontsize=14)
ax.set_xticks(index)
ax.set_xticklabels(features, rotation=45, ha='right', fontsize=10)
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Importance values for AI 4.0 and AI 5.0
importance_AI_4_0 = np.array([1, 1, 1, 1, 0, 0, 0, 0])
importance_AI_5_0 = np.array([0, 0, 0, 0, 1, 1, 1, 1])

# X-axis positions
x = np.arange(len(features))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Plot lines
ax.plot(x, importance_AI_4_0, marker='o', linestyle='-', color='lightcoral', label='AI 4.0')
ax.plot(x, importance_AI_5_0, marker='o', linestyle='-', color='lightgreen', label='AI 5.0')

# Add labels and title
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Importance', fontsize=12)
ax.set_title('Feature Importance Transition from AI 4.0 to AI 5.0', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=45, ha='right', fontsize=10)
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Importance values for AI 4.0 and AI 5.0
importance_AI_4_0 = np.array([1, 1, 1, 1, 0, 0, 0, 0])
importance_AI_5_0 = np.array([0, 0, 0, 0, 1, 1, 1, 1])

# X-axis positions
x = np.arange(len(features))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Plot lines with dots
ax.plot(x, importance_AI_4_0, marker='o', linestyle='-', color='lightcoral', label='AI 4.0')
ax.plot(x, importance_AI_5_0, marker='o', linestyle='-', color='lightgreen', label='AI 5.0')

# Add labels and title
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Importance', fontsize=12)
ax.set_title('Feature Importance Transition from AI 4.0 to AI 5.0', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=45, ha='right', fontsize=10)
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Importance values for AI 4.0 and AI 5.0
importance_AI_4_0 = np.array([1, 1, 1, 1, 0, 0, 0, 0])
importance_AI_5_0 = np.array([0, 0, 0, 0, 1, 1, 1, 1])

# X-axis positions
x = np.arange(len(features))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Plot lines with dots for AI 4.0 and AI 5.0
ax.plot(x, importance_AI_4_0, 'o-', color='blue', label='AI 4.0')
ax.plot(x, importance_AI_5_0, 'o-', color='orange', label='AI 5.0')

# Add annotations to highlight changes
for i, feature in enumerate(features):
    if importance_AI_4_0[i] == 1 and importance_AI_5_0[i] == 0:
        ax.text(i, 1.05, 'AI 4.0', ha='center', va='bottom', fontsize=9, color='blue')
    elif importance_AI_4_0[i] == 0 and importance_AI_5_0[i] == 1:
        ax.text(i, -0.05, 'AI 5.0', ha='center', va='top', fontsize=9, color='orange')
    elif importance_AI_4_0[i] == 1 and importance_AI_5_0[i] == 1:
        ax.text(i, 1.05, 'Transitioned', ha='center', va='bottom', fontsize=9, color='black')

# Customize labels and title
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Importance', fontsize=12)
ax.set_title('Evolution from AI 4.0 to AI 5.0', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=45, ha='right', fontsize=10)
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data
features = [
    "Static Algorithms",
    "Limited Adaptability",
    "Rigid Responses",
    "Hardcoded Rules",
    "Adaptive Algorithms",
    "Real-Time Feedback",
    "Contextual Awareness",
    "Continuous Learning"
]

# Importance values for AI 4.0 and AI 5.0
importance_AI_4_0 = np.array([1, 1, 1, 1, 0, 0, 0, 0])
importance_AI_5_0 = np.array([0, 0, 0, 0, 1, 1, 1, 1])

# X-axis positions
x = np.arange(len(features))

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot lines with dots
ax.plot(x, importance_AI_4_0, 'o-', color='blue', label='AI 4.0', markersize=8)
ax.plot(x, importance_AI_5_0, 'o-', color='orange', label='AI 5.0', markersize=8)

# Customize labels and title
ax.set_xlabel('Features', fontsize=12)
ax.set_ylabel('Importance', fontsize=12)
ax.set_title('Evolution from AI 4.0 to AI 5.0', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=45, ha='right', fontsize=10)
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
pip show graphviz
# Out:
# Name: graphviz
# Version: 0.20.3
# Summary: Simple Python interface for Graphviz
# Home-page: https://github.com/xflr6/graphviz
# Author: Sebastian Bank
# Author-email: sebastian.bank@uni-leipzig.de
# License: MIT
# Location: D:\jupyter notebook\Lib\site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Add nodes with labels
    G.add_node('A', label='Literature Review and Problem Definition')
    G.add_node('B', label='System Design')
    G.add_node('C', label='DQN Integration')
    G.add_node('D', label='Meta-Learning Integration')
    G.add_node('E', label='Prototype Development')
    G.add_node('F', label='Testing and Evaluation')
    G.add_node('G', label='Data Collection and Analysis')
    G.add_node('H', label='Documentation and Presentation')

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('B', 'D'),
        ('C', 'E'), ('D', 'E'), ('E', 'F'),
        ('F', 'G'), ('G', 'H')
    ])

    # Draw the graph
    pos = nx.spring_layout(G, seed=42)  # Position nodes using spring layout
    labels = nx.get_node_attributes(G, 'label')
    plt.figure(figsize=(10, 8))
    nx.draw(G, pos, with_labels=False, node_size=2000, node_color='skyblue', font_size=12, font_weight='bold', edge_color='gray')
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=10, font_weight='bold')
    plt.title('Proposed Methodology Flowchart')
    plt.show()

if __name__ == "__main__":
    draw_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Add nodes with labels
    G.add_node('A', label='Literature Review and Problem Definition')
    G.add_node('B', label='System Design')
    G.add_node('C', label='DQN Integration')
    G.add_node('D', label='Meta-Learning Integration')
    G.add_node('E', label='Prototype Development')
    G.add_node('F', label='Testing and Evaluation')
    G.add_node('G', label='Data Collection and Analysis')
    G.add_node('H', label='Deployment')
    G.add_node('I', label='Documentation and Presentation')

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('B', 'D'),
        ('C', 'E'), ('D', 'E'), ('E', 'F'),
        ('F', 'G'), ('G', 'H'), ('H', 'I')
    ])

    # Draw the graph
    pos = nx.spring_layout(G, seed=42)  # Position nodes using spring layout
    labels = nx.get_node_attributes(G, 'label')
    plt.figure(figsize=(12, 10))
    nx.draw(G, pos, with_labels=False, node_size=2000, node_color='skyblue', font_size=12, font_weight='bold', edge_color='gray')
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=10, font_weight='bold')
    plt.title('Revised Methodology Flowchart')
    plt.show()

if __name__ == "__main__":
    draw_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_adaptive_algorithms_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Add nodes with labels
    G.add_node('A', label='Literature Review and Problem Definition')
    G.add_node('B', label='System Design\n(Adaptive Algorithm Integration)')
    G.add_node('C', label='Prototype Development')
    G.add_node('D', label='Testing and Evaluation')
    G.add_node('E', label='Data Collection and Analysis')
    G.add_node('F', label='Deployment')
    G.add_node('G', label='Documentation and Presentation')

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G')
    ])

    # Draw the graph
    pos = nx.spring_layout(G, seed=42)  # Position nodes using spring layout
    labels = nx.get_node_attributes(G, 'label')
    plt.figure(figsize=(12, 10))
    nx.draw(G, pos, with_labels=False, node_size=3000, node_color='lightblue', font_size=12, font_weight='bold', edge_color='gray')
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=10, font_weight='bold')
    plt.title('Methodology Flowchart with Adaptive Algorithms')
    plt.show()

if __name__ == "__main__":
    draw_adaptive_algorithms_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_creative_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Define nodes with their labels, shapes, and colors
    nodes = {
        'A': {'label': 'Literature Review and\nProblem Definition', 'shape': 'o', 'color': 'lightcoral'},
        'B': {'label': 'System Design\n(Adaptive Algorithm Integration)', 'shape': 's', 'color': 'lightblue'},
        'C': {'label': 'Prototype Development', 'shape': 'o', 'color': 'lightgreen'},
        'D': {'label': 'Testing and Evaluation', 'shape': 's', 'color': 'lightyellow'},
        'E': {'label': 'Data Collection and Analysis', 'shape': 'o', 'color': 'lightpink'},
        'F': {'label': 'Deployment', 'shape': 's', 'color': 'lightgoldenrodyellow'},
        'G': {'label': 'Documentation and Presentation', 'shape': 'o', 'color': 'lightskyblue'}
    }

    # Add nodes to the graph
    for node, attributes in nodes.items():
        G.add_node(node, label=attributes['label'], shape=attributes['shape'], color=attributes['color'])

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G')
    ])

    # Draw the graph
    pos = nx.spring_layout(G, seed=42)  # Position nodes using spring layout
    node_shapes = {n: G.nodes[n]['shape'] for n in G.nodes}
    node_colors = [G.nodes[n]['color'] for n in G.nodes]
    labels = nx.get_node_attributes(G, 'label')
    
    plt.figure(figsize=(14, 12))

    # Draw nodes with specific shapes and colors
    for shape in set(node_shapes.values()):
        nx.draw_networkx_nodes(G, pos, nodelist=[n for n in G.nodes if node_shapes[n] == shape],
                               node_shape=shape, node_color=[G.nodes[n]['color'] for n in G.nodes if node_shapes[n] == shape],
                               node_size=3000)

    nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray')
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=10, font_weight='bold')

    plt.title('Creative Methodology Flowchart with Adaptive Algorithms')
    plt.axis('off')

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_creative_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Define nodes with their labels and colors
    nodes = {
        'A': {'label': 'Literature Review and\nProblem Definition', 'color': 'lightcoral'},
        'B': {'label': 'System Design\n(Adaptive Algorithm Integration)', 'color': 'lightblue'},
        'C': {'label': 'Prototype Development', 'color': 'lightgreen'},
        'D': {'label': 'Testing and Evaluation', 'color': 'lightyellow'},
        'E': {'label': 'Data Collection and Analysis', 'color': 'lightpink'},
        'F': {'label': 'Deployment', 'color': 'lightgoldenrodyellow'},
        'G': {'label': 'Documentation and Presentation', 'color': 'lightskyblue'}
    }

    # Add nodes to the graph
    for node, attributes in nodes.items():
        G.add_node(node, label=attributes['label'], color=attributes['color'])

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G')
    ])

    # Draw the graph
    pos = nx.spring_layout(G, seed=42)  # Position nodes using spring layout
    node_colors = [G.nodes[n]['color'] for n in G.nodes]
    labels = nx.get_node_attributes(G, 'label')

    plt.figure(figsize=(14, 12))

    # Draw nodes
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=3000, edgecolors='black')
    
    # Draw edges
    nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray')
    
    # Draw labels
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=10, font_weight='bold')

    plt.title('Creative Methodology Flowchart with Adaptive Algorithms')
    plt.axis('off')  # Hide the axis
    plt.show()

if __name__ == "__main__":
    draw_creative_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_compact_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Define nodes with their labels, shapes, and colors
    nodes = {
        'A': {'label': 'Literature Review\nand Problem Definition', 'color': 'lightcoral'},
        'B': {'label': 'System Design\n(Adaptive Algorithm Integration)', 'color': 'lightblue'},
        'C': {'label': 'Prototype Development', 'color': 'lightgreen'},
        'D': {'label': 'Testing and Evaluation', 'color': 'lightyellow'},
        'E': {'label': 'Data Collection\nand Analysis', 'color': 'lightpink'},
        'F': {'label': 'Deployment', 'color': 'lightgoldenrodyellow'},
        'G': {'label': 'Documentation\nand Presentation', 'color': 'lightskyblue'}
    }

    # Add nodes to the graph
    for node, attributes in nodes.items():
        G.add_node(node, label=attributes['label'], color=attributes['color'])

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G')
    ])

    # Draw the graph
    pos = nx.spring_layout(G, seed=42, k=0.5)  # Use a tighter layout to reduce space
    node_colors = [G.nodes[n]['color'] for n in G.nodes]
    labels = nx.get_node_attributes(G, 'label')

    plt.figure(figsize=(10, 8))

    # Draw nodes with edge color and node color
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=2500, edgecolors='black', alpha=0.9)
    
    # Draw edges
    nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray', alpha=0.7)
    
    # Draw labels
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=9, font_weight='bold')

    plt.title('Compact and Innovative Methodology Flowchart')
    plt.axis('off')  # Hide the axis
    plt.tight_layout()  # Adjust layout to minimize unwanted spaces
    plt.show()

if __name__ == "__main__":
    draw_compact_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_circular_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Define nodes with their labels and colors
    nodes = {
        'A': {'label': 'Literature Review\nand Problem Definition', 'color': 'lightcoral'},
        'B': {'label': 'System Design\n(Adaptive Algorithm Integration)', 'color': 'lightblue'},
        'C': {'label': 'Prototype Development', 'color': 'lightgreen'},
        'D': {'label': 'Testing and Evaluation', 'color': 'lightyellow'},
        'E': {'label': 'Data Collection\nand Analysis', 'color': 'lightpink'},
        'F': {'label': 'Deployment', 'color': 'lightgoldenrodyellow'},
        'G': {'label': 'Documentation\nand Presentation', 'color': 'lightskyblue'}
    }

    # Add nodes to the graph
    for node, attributes in nodes.items():
        G.add_node(node, label=attributes['label'], color=attributes['color'])

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G'), ('G', 'A')
    ])

    # Draw the graph
    pos = nx.circular_layout(G)  # Circular layout
    node_colors = [G.nodes[n]['color'] for n in G.nodes]
    labels = nx.get_node_attributes(G, 'label')

    plt.figure(figsize=(10, 10))

    # Draw nodes
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=3000, edgecolors='black', alpha=0.9)
    
    # Draw edges
    nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray', alpha=0.7)
    
    # Draw labels
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=9, font_weight='bold')

    plt.title('Circular Flowchart with Adaptive Algorithms')
    plt.axis('off')  # Hide the axis
    plt.show()

if __name__ == "__main__":
    draw_circular_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_radial_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Define nodes with their labels and colors
    nodes = {
        'A': {'label': 'Literature Review\nand Problem Definition', 'color': 'lightcoral'},
        'B': {'label': 'System Design\n(Adaptive Algorithm Integration)', 'color': 'lightblue'},
        'C': {'label': 'Prototype Development', 'color': 'lightgreen'},
        'D': {'label': 'Testing and Evaluation', 'color': 'lightyellow'},
        'E': {'label': 'Data Collection\nand Analysis', 'color': 'lightpink'},
        'F': {'label': 'Deployment', 'color': 'lightgoldenrodyellow'},
        'G': {'label': 'Documentation\nand Presentation', 'color': 'lightskyblue'}
    }

    # Add nodes to the graph
    for node, attributes in nodes.items():
        G.add_node(node, label=attributes['label'], color=attributes['color'])

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G')
    ])

    # Draw the graph
    pos = nx.shell_layout(G, nlist=[['A'], ['B', 'C', 'D', 'E', 'F', 'G']])  # Radial layout
    node_colors = [G.nodes[n]['color'] for n in G.nodes]
    labels = nx.get_node_attributes(G, 'label')

    plt.figure(figsize=(12, 12))

    # Draw nodes
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=3000, edgecolors='black', alpha=0.9)
    
    # Draw edges
    nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray', alpha=0.7)
    
    # Draw labels
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=9, font_weight='bold')

    plt.title('Radial Flowchart with Adaptive Algorithms')
    plt.axis('off')  # Hide the axis
    plt.show()

if __name__ == "__main__":
    draw_radial_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_circular_flowchart():
    # Create a directed graph
    G = nx.DiGraph()

    # Define nodes with their labels and colors
    nodes = {
        'A': {'label': 'Literature Review\nand Problem Definition', 'color': 'lightcoral'},
        'B': {'label': 'System Design\n(Adaptive Algorithm Integration)', 'color': 'lightblue'},
        'C': {'label': 'Prototype Development', 'color': 'lightgreen'},
        'D': {'label': 'Testing and Evaluation', 'color': 'lightyellow'},
        'E': {'label': 'Data Collection\nand Analysis', 'color': 'lightpink'},
        'F': {'label': 'Deployment', 'color': 'lightgoldenrodyellow'},
        'G': {'label': 'Documentation\nand Presentation', 'color': 'lightskyblue'}
    }

    # Add nodes to the graph
    for node, attributes in nodes.items():
        G.add_node(node, label=attributes['label'], color=attributes['color'])

    # Add edges between nodes
    G.add_edges_from([
        ('A', 'B'), ('B', 'C'), ('C', 'D'),
        ('D', 'E'), ('E', 'F'), ('F', 'G'), ('G', 'A')
    ])

    # Draw the graph
    pos = nx.circular_layout(G)  # Circular layout
    node_colors = [G.nodes[n]['color'] for n in G.nodes]
    labels = nx.get_node_attributes(G, 'label')

    plt.figure(figsize=(12, 12))

    # Draw nodes with edge color and node color
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=3000, edgecolors='black', alpha=0.9)
    
    # Draw edges
    nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20, edge_color='gray', alpha=0.7)
    
    # Draw labels with improved font clarity
    nx.draw_networkx_labels(G, pos, labels=labels, font_size=12, font_weight='bold', bbox=dict(facecolor='white', edgecolor='none', boxstyle='round,pad=0.3'))

    plt.title('Circular Flowchart for Methodology with Adaptive Algorithms', fontsize=14, fontweight='bold')
    plt.axis('off')  # Hide the axis
    plt.show()

if __name__ == "__main__":
    draw_circular_flowchart()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes for Adaptive Algorithms
G.add_node("Adaptive Algorithms")
G.add_node("Reinforcement Learning (RL)")
G.add_node("Bayesian Networks")
G.add_node("Adaptive Neural Networks")
G.add_node("Ensemble Methods")

# Add nodes and edges for RL
G.add_node("Q-Learning")
G.add_node("DQN")
G.add_node("Policy Gradient Methods")
G.add_edge("Reinforcement Learning (RL)", "Q-Learning")
G.add_edge("Reinforcement Learning (RL)", "DQN")
G.add_edge("Reinforcement Learning (RL)", "Policy Gradient Methods")

# Add nodes and edges for Bayesian Networks
G.add_node("Bayesian Optimization")
G.add_node("Adaptive Bayesian Inference")
G.add_edge("Bayesian Networks", "Bayesian Optimization")
G.add_edge("Bayesian Networks", "Adaptive Bayesian Inference")

# Add nodes and edges for Adaptive Neural Networks
G.add_node("Meta-learning")
G.add_node("Elastic Weight Consolidation (EWC)")
G.add_edge("Adaptive Neural Networks", "Meta-learning")
G.add_edge("Adaptive Neural Networks", "Elastic Weight Consolidation (EWC)")

# Add nodes and edges for Ensemble Methods
G.add_node("AdaBoost")
G.add_node("Random Forest with Adaptive Sampling")
G.add_edge("Ensemble Methods", "AdaBoost")
G.add_edge("Ensemble Methods", "Random Forest with Adaptive Sampling")

# Add nodes for Real-Time Algorithms
G.add_node("Real-Time Algorithms")
G.add_node("Real-Time Reinforcement Learning")
G.add_node("Kalman Filters")
G.add_node("Online Learning Algorithms")
G.add_node("Real-Time Scheduling Algorithms")

# Add nodes and edges for Real-Time Algorithms
G.add_node("Extended Kalman Filter (EKF)")
G.add_node("Stochastic Gradient Descent (SGD)")
G.add_node("Decision Trees with Incremental Learning")
G.add_node("Earliest Deadline First (EDF)")
G.add_node("Rate-Monotonic Scheduling (RMS)")

G.add_edge("Kalman Filters", "Extended Kalman Filter (EKF)")
G.add_edge("Online Learning Algorithms", "Stochastic Gradient Descent (SGD)")
G.add_edge("Online Learning Algorithms", "Decision Trees with Incremental Learning")
G.add_edge("Real-Time Scheduling Algorithms", "Earliest Deadline First (EDF)")
G.add_edge("Real-Time Scheduling Algorithms", "Rate-Monotonic Scheduling (RMS)")

# Create edges between main categories
G.add_edge("Adaptive Algorithms", "Reinforcement Learning (RL)")
G.add_edge("Adaptive Algorithms", "Bayesian Networks")
G.add_edge("Adaptive Algorithms", "Adaptive Neural Networks")
G.add_edge("Adaptive Algorithms", "Ensemble Methods")
G.add_edge("Real-Time Algorithms", "Real-Time Reinforcement Learning")
G.add_edge("Real-Time Algorithms", "Kalman Filters")
G.add_edge("Real-Time Algorithms", "Online Learning Algorithms")
G.add_edge("Real-Time Algorithms", "Real-Time Scheduling Algorithms")

# Draw the graph
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold', arrows=True, arrowsize=20)
plt.title('Algorithms for Adaptive Human-AI Dynamics')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Define the data for the comparison matrix
data = {
    "Algorithm": ["Q-Learning", "Extended Kalman Filter (EKF)", "Stochastic Gradient Descent (SGD)", "Meta-learning"],
    "Type": ["Adaptive", "Real-Time", "Real-Time", "Adaptive"],
    "Key Features": [
        "Optimizes actions based on rewards.",
        "Accurate real-time tracking in dynamic systems.",
        "Updates models incrementally with new data.",
        "Adapts to new tasks quickly."
    ],
    "Advantages": [
        "Simple, effective for discrete actions.",
        "Accurate tracking in real-time.",
        "Fast convergence, online updates.",
        "Quick adaptation to new tasks."
    ],
    "Use Cases": [
        "Game AI, robotics",
        "Robotics, navigation systems",
        "Machine learning, neural networks",
        "Transfer learning, quick adaptation"
    ]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Create a heatmap with a black background
plt.figure(figsize=(12, 6))
sns.heatmap(df.iloc[:, 1:], annot=df, fmt='', cmap='Blues', cbar=False, linewidths=.5, linecolor='black', vmin=0, vmax=1)

# Customize plot appearance
plt.title('Comparison Matrix of Algorithms for Adaptive Human-AI Dynamics', fontsize=16, color='white')
plt.gca().set_facecolor('black')
plt.xticks(rotation=45, ha='right', color='white')
plt.yticks(color='white')
plt.xlabel('Attributes', fontsize=14, color='white')
plt.ylabel('Algorithms', fontsize=14, color='white')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 34
#      32 # Create a heatmap with a black background
#      33 plt.figure(figsize=(12, 6))
# ---> 34 sns.heatmap(df.iloc[:, 1:], annot=df, fmt='', cmap='Blues', cbar=False, linewidths=.5, linecolor='black', vmin=0, vmax=1)
#      36 # Customize plot appearance
#      37 plt.title('Comparison Matrix of Algorithms for Adaptive Human-AI Dynamics', fontsize=16, color='white')
#
# File D:\jupyter notebook\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Define the data for the comparison matrix
data = {
    "Algorithm": ["Q-Learning", "Extended Kalman Filter (EKF)", "Stochastic Gradient Descent (SGD)", "Meta-learning"],
    "Type": ["Adaptive", "Real-Time", "Real-Time", "Adaptive"],
    "Key Features": [
        "Optimizes actions based on rewards.",
        "Accurate real-time tracking in dynamic systems.",
        "Updates models incrementally with new data.",
        "Adapts to new tasks quickly."
    ],
    "Advantages": [
        "Simple, effective for discrete actions.",
        "Accurate tracking in real-time.",
        "Fast convergence, online updates.",
        "Quick adaptation to new tasks."
    ],
    "Use Cases": [
        "Game AI, robotics",
        "Robotics, navigation systems",
        "Machine learning, neural networks",
        "Transfer learning, quick adaptation"
    ]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Create a plot with a black background
fig, ax = plt.subplots(figsize=(12, 6))
ax.axis('off')  # Hide axes

# Create the table
table = ax.table(cellText=df.values,
                 colLabels=df.columns,
                 rowLabels=df['Algorithm'],
                 cellLoc='center',
                 loc='center',
                 cellColours=[['#1f77b4']*len(df.columns) for _ in range(len(df))], # Set cell color to blue
                 rowColours=['#1f77b4']*len(df['Algorithm']), # Set row color to blue
                 colColours=['#1f77b4']*len(df.columns), # Set header color to blue
                 colColours=['#ffffff']*len(df.columns), # Set header text color to white
                 rowColours=['#ffffff']*len(df['Algorithm']), # Set row text color to white
                 )

# Customize table appearance
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)
table.auto_set_column_width([0, 1, 2, 3, 4])

# Set background color
fig.patch.set_facecolor('black')

# Set title
plt.title('Comparison Matrix of Algorithms for Adaptive Human-AI Dynamics', fontsize=16, color='white')

# Show plot
plt.show()
# Out:
#   Cell In[7], line 46
#     rowColours=['#ffffff']*len(df['Algorithm']), # Set row text color to white
#     ^
# SyntaxError: keyword argument repeated: rowColours

# %%
import matplotlib.pyplot as plt

# Data
categories = ['End Users', 'Businesses', 'Developers and Researchers', 'Healthcare and Education', 'Policy Makers']
values = [25, 25, 20, 20, 10]  # Example values for each category

# Create Bar Chart
fig, ax = plt.subplots()
ax.bar(categories, values, color=plt.cm.Paired(range(len(categories))))

# Add title and labels
plt.title('Beneficiaries of the AI 5.0 Project')
plt.xlabel('Beneficiary Categories')
plt.ylabel('Impact Percentage')

# Show plot
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()
